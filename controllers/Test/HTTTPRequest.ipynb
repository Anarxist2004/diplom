# %%
import requests

# %%
url = "http://127.0.0.1:8000/techcard/object"

data={}
response = requests.post(url, json=data)

print("Статус:", response.status_code)
print("Ответ:", response.json())
# Out:
# Статус: 200
# Ответ: {
#   "params": {},
#   "available": {
#     "0": "Пластина",
#     "1": "Труба"
#   }
# }

# %%
url = "http://127.0.0.1:8000/techcard/element"

data={"params":1}
response = requests.post(url, json=data)

print("Статус:", response.status_code)
print("Ответ:", response.json())
# Out:
# Статус: 200
# Ответ: {
#   "params": {},
#   "available": {
#     "4": "Труба Д250x8; ATS-0002-21",
#     "1": "Труба Д273x8; АТС-0001-21",
#     "3": "Труба Д400x12; РГК-0001-16\n"
#   }
# }

# %%
url = "http://127.0.0.1:8000/techcard/elementParams"

data={"params":1}
response = requests.post(url, json=data)

print("Статус:", response.status_code)
print("Ответ:", response.json())
# Out:
# Статус: 200
# Ответ: {
#   "params": {},
#   "available": {
#     "4": "Категория по ПНАЭ Г-7-010-89",
#     "2": "Наружный диаметр",
#     "3": "Размер контролируемых элементов"
#   }
# }

# %%
url = "http://127.0.0.1:8000/techcard/elementParamValue"

data={"params":[1,2]}
response = requests.post(url, json=data)

print("Статус:", response.status_code)
print("Ответ:", response.json())
# Out:
# Статус: 500
# Ответ: {'detail': "'NoneType' object has no attribute 'serialise'"}
